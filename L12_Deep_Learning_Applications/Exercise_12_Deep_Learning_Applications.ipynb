# %% [markdown]
# # **Exercise 12: Deep Learning Applications**

# %% [markdown]
# ## **Exercise/Home Assignment (Competition) 12.1: Application**

# %% [markdown]
# Use the tools you learned throughout the AI & Data Science lecture to work on a problem of your choice. For example, you can find yourself an intresting dataset, analyze it, train models from previous lectures on it, or design your own models. In the next lecture, you will have the opportunity to present your results. Feel free to reuse code from previous exercises. The most interesting and best worked on assignment wins the final round! Be creative!
